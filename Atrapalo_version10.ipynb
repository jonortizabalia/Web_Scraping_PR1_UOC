# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Variables" data-toc-modified-id="Variables-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Variables</a></span></li><li><span><a href="#Funciones" data-toc-modified-id="Funciones-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Funciones</a></span></li><li><span><a href="#Programa-Ppal" data-toc-modified-id="Programa-Ppal-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Programa Ppal</a></span></li><li><span><a href="#i+d" data-toc-modified-id="i+d-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>i+d</a></span></li></ul></div>

# %% [markdown]
# # Variables

# %%
import requests
from lxml import html
from bs4 import BeautifulSoup
import pandas as pd
import openpyxl
import datetime
import random
import re
import csv
import os
import time   # v05 
import getpass #v05 Necesraio para detectar el user loggeado actualmente en el sistema


# ahora = datetime.datetime.now()
# ahora.year


######## Codigo PERSONAL###############
proxy_on = False

proxies_home = None
proxies_work = {
    "http": (removed) ,
    "https": (removed),
}

if proxy_on:
    proxies = proxies_work
else:
    proxies = proxies_home
########################################

headers={
    "Accept": "*/*",
    "Content-Encoding": "gzip",
    "Cache-Control": "max-age=1206531",
    "Connection": "keep-alive",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36",
}

URL = "https://www.atrapalo.com/entradas/"

SECCIONES = {'teatro-y-danza' : 'Teatro y Danza', 
           'musica': 'Música', 
           'parques-tematicos': 'Parques temáticos', 
            'musicales': 'Musicales',
            'museos-y-exposiciones':'Museos y Exposiciones',
            'deportes':'Deportes',
            'circo': 'Circo',
            'cine': 'Cine',
            'ferias':'Ferias'}


#SECCIONES = {'teatro-y-danza' : 'Teatro y Danza'}
#SECCIONES = {'teatro-y-danza' : 'Teatro y Danza', 'circo' : 'Circo','musica': 'Música'}
#SECCIONES = {'circo' : 'Circo','teatro-y-danza' : 'Teatro y Danza'}

#atributos = ["Titulo","Categoria","Novedad","Ubicación","Localidad","Precio","Descuento", # -Añadida en v04
#                     "Fechas", "Fecha_inicio", "Fecha_fin","Duracion","Idioma","Publico",
#                     "Puntuación","Valoración","Opiniones"]

# v05  Añadidos nuevos atributos Captura, Web, Evento
atributos = ["Captura", "Web", "Evento", 
             "Titulo","Categoria","Novedad","Ubicación","Localidad","Precio","Descuento", 
             "Fechas", "Fecha_inicio", "Fecha_fin","Duracion","Idioma","Publico",
             "Puntuación","Valoración","Opiniones"]

origen = 'Atrapalo'    # Añadido en  v05

# path = "C:/Users/Usuario/Desktop/output.csv" # -Añadida en v04

fichero_csv = 'output.csv'
# v05. Permite obviar el usuario con el que se haya loggeado el usuario en el sistema
path = "C:/Users/" + getpass.getuser() + "/Desktop/" + fichero_csv  # Añadido v05

# Estas variables sirven para controlar el número de registros a descargar
modo_prueba = False
pantallazos = 2  #100 registros de pruebas (5 pantallazos x 20 registros)

# %% [markdown]
# # Funciones

# %%
# Desarrollo de funciones

'''
DESCRIPCIÓN: 
Función a la que se le pasa la URL de la web ATRAPALO para que se descargue todos los espectaculos que se listan
en el apartado de 'entradas' 

    INPUT: 
        url (string) : URL de Atrapalo   
    
    OUTPUT: 
        nuevos_espectaculos (list): lista con todos los espectaculos encontrados

''' 

def Sacar_espectaculos(url):
    
    # Leemos espectaculos de la url indicada
    respuesta = requests.get(url, proxies=proxies, headers=headers)
    status = "Correcto" if respuesta.status_code else "Error"
    # print("Rta:",respuesta.status_code)  # -Obseleto v02
    
    
    # Parseamos la respuesta para sacar los contenedores de cada espectaculo
    soup = BeautifulSoup(respuesta.content, "html.parser")
    url_espectaculos = soup.find_all(class_="card-result-container")    
    
    # Mostramos msg y devolvemos resultado
    #print(f"Descargando URL: {url} | Espectaculos Leidos: {len(nuevos_espectaculos)} | Status: {status}")  #Obsoleto v07
    return(url_espectaculos, status)  # v07. Devolvemos tb el estado de la operación
    
    
'''
DESCRIPCIÓN: 
Función a la que se le pasa el código html de cada uno de los espectaculos y devuelve una tupla con los atributos extraidos

    INPUT: 
        espectaculos[N]    donde N corresponde el N-ésimo espectáculo obtenido
    
    OUTPUT: 
        atributos (tupla) donde se entregan todos los atributos extráidos. Concretamente los siguientes atributos:
        captura, web, evento, titulo, categoria, novedad, ubicacion, localidad, precio, descuento, fechas, fecha_inicio, fecha_fin, duracion,
        idioma, publico, puntuacion, valoracion, opiniones

''' 

def Sacar_atributos(espectaculo):
    
     # vamos extrayendo los diferentes atributos
    
    # Captura  v05
    captura = time.strftime("%d/%m/%Y %H:%M")   #Fecha de hoy en formato dd/mm/aa  HH:MM
    
    # Web v05
    web = origen
    
    # seccion  v05
    evento = seccion.replace('-y-','-')
    
    # Titulo
    try: titulo= espectaculo.find_all('h2')[0].text.strip('\n')
    except: titulo = ""
        
    # Categoria
    try:
        #categoria = espectaculo.find(class_="type large-loc").text.strip()
        categoria = espectaculo.find(class_="type large-loc").text.strip().split()[0]
    except: categoria = ""   
        
    # Novedad
    try: 
        novedad = espectaculo.find(class_="sticker-box sticker-new").text.strip() # Modificado en v06
        novedad = "" # Transitorio . Habría que borrarlo
    except: novedad = ""    
        
    # Ubicacion
    try: #ubicacion = espectaculo.find_all(class_="info")[0].find('a').text.strip()
         ubicacion = espectaculo.find_all(class_="info")[0].span.text.strip("\n").strip().split("\n")[0] # v09
    except: ubicacion = ""    
    
    # Localidad (Modificada en v06)
    try:    
        a = espectaculo.find("p", class_="info").span.text.strip()
        b = re.findall("\(.*\)",a)
        if len(b) == 1:
            c = b[0]
            localidad = re.sub('[(){}<>]', '', c)
        elif len(b) == 2:
            c = b[1]
            localidad = re.sub('[(){}<>]', '', c)
        #localidad = espectaculo.find("p", class_="info").span.text.split()[2].strip('()')
    except: localidad = ""
        
    # Precio
    try: 
        valor = espectaculo.find(class_="value").text.strip()
        precio = re.sub('€', '', valor)
        
    except: precio = ""
        
    # Descuento
    try: 
        valor_desc = espectaculo.find(class_="status-label").span.text.strip()
        descuento = re.sub('€', '', valor_desc)
        
    except: descuento = ""                   
        
    # Fechas en cartel, inicial y final
    try:
        num = espectaculo.find_all(class_="info")[1].find_all('span')
        fechas = espectaculo.find_all(class_="info")[1].find_all('span')[0].text.strip()
        
        if len(num) >=3:
            fecha_inicio= espectaculo.find_all(class_="info")[1].find_all('span')[1].span['title'].strip()
            fecha_fin= espectaculo.find_all(class_="info")[1].find_all('span')[4]['title'].strip()
        else: 
            fecha_inicio = espectaculo.find_all(class_="info")[1].find_all('span')[1]['title'].strip()
            fecha_fin = fecha_inicio.strip()
    except: 
        fechas = ""
        fecha_inicio = ""
        fecha_fin = ""
        
    # Duracion (modificada en versión v06)
    try: #duracion = espectaculo.find_all(class_="info")[2].get_text().strip('\n').strip() 
        if espectaculo.find(class_="icon-reloj_2"):
            duracion = espectaculo.find_all(class_="info")[2].text.strip()
        else:
            duracion ="NA"
    except: duracion = ""
    
    # Idioma
    try:
        if len(espectaculo.find_all(class_="info")) == 4:
            idioma = espectaculo.find_all(class_="info")[3].get_text().strip('\n').strip()
        else:
            idioma = ""
    except: idioma = ""
    
    # Publico
    try: publico = espectaculo.find(class_="item-tag").text.strip()
    except: publico = ""
    
    # Puntuacion
    try: puntuacion = espectaculo.find(class_="opi-rating").text.strip('\n').strip()
    except: puntuacion = ""
    
    # Valoracion
    try: valoracion = espectaculo.find(class_="opi-description").a.text.strip('\n').strip()
    except: valoracion = ""
    
    # Opiniones
    try: opiniones = espectaculo.find(class_="opi-description").span.text.strip('\n').strip()
    except: opiniones = ""    
            
    # Devolvemos valores
    
    atributos = (captura,
                 web,
                 evento,
                 titulo,
                 categoria,
                 novedad,
                 ubicacion,
                 localidad,
                 precio,
                 descuento,
                 fechas,
                 fecha_inicio,
                 fecha_fin,
                 duracion,
                 idioma,
                 publico,
                 puntuacion,
                 valoracion,
                 opiniones)
    
    return (atributos)

# Función añadida en -version 04
''' 
DESCRIPCIÓN: 
Función a la que se le pasa una ruta de localización de archivo, una n-tupla y la lista de atributos
y devuelve un archivo en formato .csv en la ruta pasada por parámetro.


    INPUT: 
        path: ruta de localización del archivo a generar
        rows: n-tupla generada por la iteración de la función Sacar_atributos[N] donde N corresponde el N-ésimo espectáculo obtenido
        atributos: lista de atributos    
    
    OUTPUT: 
        archivo en formato .csv con el contenido (header + rows)
''' 

def crear_csv(path, rows, atributos):
    with open(path, "w+", newline='') as f:
        writer = csv.writer(f)
        writer.writerow(atributos)
        for row in rows:
            writer.writerow(row)

# %% [markdown]
# # Programa Ppal

# %%
'''
PROGRAMA PRINCIPAL
'''

espectaculos = []  # Variable donde cargaremos inicialmente todos los registros que nos descargamos
espectaculos_pantalla_anterior = []  #Variable temporal que sirve para el flujo del programa
espectaculos_bbdd = []    # Variable donde cargaremos todos los registros acumulados en la bbdd actual (fichero .csv)
espectaculos_a_bbdd = []  #  Variable donde almacenaremos todos los registros a volcar a la bbdd
espectaculos_nuevos = []  # Guardamos los registros nuevos descargados que no estaban en la bbdd

#espectaculos_dataframe   Variable donde tenemos el dataframe de todos los espectaculos descargados
#espectaculos_bbdd_dataframe Variable donde tenemos el dataframe de todos los espectaculos de la bbdd actual, previo a la descarga
#espectaculos_nuevos_dataframe  Variable donde tenemos el dataframe de todos los espectaculos estrictamente nuevos 
#espectaculos_a_bbdd_dataframe  Variable con todos los registros que escribiremos en la bbdd

print(f"Iniciando proceso de descarga.....\n")
for seccion in SECCIONES:
    cont = 1
    seguir_buscando = True
    while seguir_buscando:
        if cont == 0:
            url = URL + seccion + '/'
        else: 
            url = URL + seccion + '/' + 'p-' + str(cont) + '/'
        cont += 1
    
        
        # Controlamos si nos descargamos todos los registros de cada sección o solo unos de prueba
        if modo_prueba and cont == (pantallazos + 1):
            
            seguir_buscando = False
        
        espectaculos_pantalla, status = Sacar_espectaculos(url) # v07 capturamos 2 valores de la función
        
        if espectaculos_pantalla == espectaculos_pantalla_anterior:
            seguir_buscando = False
        else:
            
            print(f"Descargando URL: {url} | Espectaculos Leidos: {len(espectaculos_pantalla)} | Status: {status}") # v07 se saca de la fn
            
            
            for espectaculo in espectaculos_pantalla:
                
                #La lista de espectaculos se compondrá de las tuplas correspondientes a cada espectaculo
                espectaculos.append(Sacar_atributos(espectaculo))   # - Nuevo v07. Quitamos el campo Captura
            
            espectaculos_pantalla_anterior = espectaculos_pantalla 
    


print(f"\n Finalizado proceso. Espectaculos descargados: {len(espectaculos)}")
espectaculos_original = espectaculos

# Procedemos a salvar la informacion a fichero
try: 
    
    # Leemos el historico de espectaculos existente en la bbdd
    
    
    espectaculos_bbdd_dataframe = pd.read_csv(path, encoding = "ISO-8859-1", keep_default_na=False)  # 
    print(f"\n Cargando fichero histórico de espectáculos : {path}")
    
    
    for fila in espectaculos_bbdd_dataframe.iterrows():
        espectaculos_bbdd.append(tuple(fila[1])) # generamos una lista de tuplas. En el indice 0 se guarda el indice de fila
    
    
    # Sacamos los espectaculos nuevos que todavía no están en la bbdd
    # La unicidad de cada registro tanto en la bbdd existente como en el listado descargado se compone de 2 atributos: titulo + ubicacion
    titulo = 3
    ubicacion = 6
    
    espectaculos_uids = [atrib for atrib in ((espectaculo[titulo], espectaculo[ubicacion]) for espectaculo in espectaculos_original)]
    espectaculos_bbdd_uids = [atrib for atrib in ((espectaculo[titulo],espectaculo[ubicacion]) for espectaculo in espectaculos_bbdd)]
    
    total_nuevos_registros = len(set(espectaculos_uids) - set(espectaculos_bbdd_uids))

    # Identificamos los identificadores  que ya se encontraban en la bbdd pero no en el listado descargado
    # y que correspondería a los espectaculos antiguos
    for espectaculo in espectaculos_bbdd:
        
        identificador_registro = (espectaculo[titulo],espectaculo[ubicacion]) # id= Titulo + Ubicacion
        if identificador_registro not in espectaculos_uids:
            espectaculos_a_bbdd.append(tuple(espectaculo))
            
            #print(tuple(espectaculo))
            
        
    # Identificamos el listado a cargar con los nuevos + la actualización de los que ya existían
    for espectaculo in espectaculos:
        espectaculo = [elem for elem in espectaculo]
        espectaculos_a_bbdd.append(tuple(espectaculo))
        
        #Extraemos el listado de registros nuevos exclusivamente 
        identificador_registro = (espectaculo[titulo],espectaculo[ubicacion]) # id= Titulo + Ubicacion
        if identificador_registro not in espectaculos_bbdd_uids: 
            espectaculos_nuevos.append(tuple(espectaculo))
            #print(identificador_registro)
    
    
    print(f"\n Nuevos espectáculos agregados a bbdd: {total_nuevos_registros}")
    

    
    espectaculos_nuevos_dataframe = pd.DataFrame([espectaculo for espectaculo in espectaculos_nuevos], columns = atributos)
    
    espectaculos_a_bbdd_dataframe = pd.DataFrame([espectaculo for espectaculo in espectaculos_a_bbdd], columns = atributos)
    espectaculos_a_bbdd_dataframe.to_csv(path, index = False, encoding ="ISO-8859-1") # Modificado en v10
    
    
        
except FileNotFoundError: 
    
    # El fichero csv no existe por lo que procedemos a cargarlo
    # Guardamos la primera carga en archivo csv
    crear_csv(path, espectaculos, atributos) # Añadido en version-04
    print(f"\n Creando nuevo fichero de bbdd en : {path}")


# DataFrame donde se encuentra todo el listado de registros descaragado
espectaculos_dataframe = pd.DataFrame([espectaculo for espectaculo in espectaculos],
                                      columns = atributos)
# Out:
# Iniciando proceso de descarga.....
#
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-1/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-2/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-3/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-4/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-5/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-6/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-7/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-8/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-9/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-10/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-11/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-12/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-13/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-14/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-15/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-16/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-17/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-18/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-19/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-20/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-21/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-22/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-23/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-24/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-25/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-26/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-27/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-28/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-29/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-30/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-31/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-32/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-33/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-34/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-35/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-36/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-37/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-38/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-39/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-40/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-41/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-42/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-43/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-44/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-45/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-46/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-47/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-48/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/teatro-y-danza/p-49/ | Espectaculos Leidos: 9 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/musica/p-1/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/musica/p-2/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/musica/p-3/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/musica/p-4/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/musica/p-5/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/musica/p-6/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/musica/p-7/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/musica/p-8/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/musica/p-9/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/musica/p-10/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/musica/p-11/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/musica/p-12/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/musica/p-13/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/musica/p-14/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/musica/p-15/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/musica/p-16/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/musica/p-17/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/musica/p-18/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/musica/p-19/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/musica/p-20/ | Espectaculos Leidos: 4 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/parques-tematicos/p-1/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/parques-tematicos/p-2/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/parques-tematicos/p-3/ | Espectaculos Leidos: 15 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/musicales/p-1/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/musicales/p-2/ | Espectaculos Leidos: 19 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/museos-y-exposiciones/p-1/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/museos-y-exposiciones/p-2/ | Espectaculos Leidos: 19 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/deportes/p-1/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/deportes/p-2/ | Espectaculos Leidos: 9 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/circo/p-1/ | Espectaculos Leidos: 20 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/circo/p-2/ | Espectaculos Leidos: 2 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/cine/p-1/ | Espectaculos Leidos: 4 | Status: Correcto
# Descargando URL: https://www.atrapalo.com/entradas/ferias/p-1/ | Espectaculos Leidos: 2 | Status: Correcto
#
#  Finalizado proceso. Espectaculos descargados: 1543
#
#  Cargando fichero histórico de espectáculos : C:/Users/Usuario/Desktop/output.csv
#
#  Nuevos espectáculos agregados a bbdd: 549

# %% [markdown]
# # i+d

# %%
len(set(espectaculos_uids) - set(espectaculos_bbdd_uids))
set(espectaculos_bbdd_uids)
set(espectaculos_uids) - set(espectaculos_bbdd_uids)
set(espectaculos_bbdd_uids) - set(espectaculos_uids)
len(espectaculos_a_bbdd)
espectaculos_a_bbdd
espectaculos_dataframe   #Variable donde tenemos el dataframe de todos los espectaculos descargados
espectaculos_bbdd_dataframe #Variable donde tenemos el dataframe de todos los espectaculos de la bbdd actual, previo a la descarga
espectaculos_nuevos_dataframe  #Variable donde tenemos el dataframe de todos los espectaculos estrictamente nuevos 
espectaculos_a_bbdd_dataframe  #Variable con todos los registros que escribiremos en la bbdd
# Out:
#                Captura       Web             Evento  \
# 0     07/04/2019 10:04  Atrapalo       teatro-danza
# 9                      Para todas las edades        7.2           Bueno
# 10                     Para todas las edades        7.9           Bueno
# 11                     Para todas las edades        7.9           Bueno
# 12                     Para todas las edades        8.3       Muy bueno
# 13                     Para todas las edades        8.5       Excelente
# 14                     Para todas las edades        8.0       Muy bueno
# 15                     Para todas las edades        7.5           Bueno
# 16                     Para todas las edades        7.5           Bueno
# 17            Español  Para todas las edades        7.0           Bueno
# 18                     Para todas las edades        7.0           Bueno
# 19                     Para todas las edades        7.0           Bueno
# 20                     Para todas las edades        7.8           Bueno
# 21                     Para todas las edades        8.6       Excelente
# 22                     Para todas las edades        7.2           Bueno
# 23            Español  Para todas las edades        7.1           Bueno
# 24    Español, Inglés  Para todas las edades        7.2           Bueno
# 25            Español  Para todas las edades        6.9        Correcto
# 26                     Para todas las edades        5.3
# 27                     Para todas las edades
# 28                     Para todas las edades        8.5       Excelente
# 29                     Para todas las edades        8.5       Excelente
# ...               ...                    ...        ...             ...
# 1532          Español                Adultos
# 1533                   Para todas las edades
# 1534       Castellano               Familiar        7.8           Bueno
# 1535          Español               Familiar        6.7        Correcto
# 1536          Español               Familiar        8.0       Muy bueno
# 1537       Castellano               Familiar        9.3  Extraordinario
# 1538          Español               Familiar        7.2           Bueno
# 1539       Castellano                Adultos
# 1540          Español               Familiar        6.7        Correcto
# 1541       Castellano                Adultos        9.1  Extraordinario
# 1542       Castellano                Adultos        8.7       Excelente
# 1543          Español               Familiar
# 1544          Español  Para todas las edades
# 1545          Español               Familiar
# 1546                                Familiar
# 1547       Castellano               Familiar        9.3  Extraordinario
# 1548          Español               Familiar        7.2           Bueno
# 1549         Valencià                Adultos
# 1550       Castellano  Para todas las edades
# 1551       Castellano                Adultos
# 1552       Castellano                Adultos
# 1553                   Para todas las edades
# 1554                   Para todas las edades
# 1555                   Para todas las edades
# 1556                   Para todas las edades
# 1557                   Para todas las edades
# 1558                   Para todas las edades
# 1559                   Para todas las edades
# 1560       Castellano               Infantil
# 1561                   Para todas las edades
#
#            Opiniones
# 0       92 opiniones
# 1     1811 opiniones
# 2      101 opiniones
# 3       66 opiniones
# 4      439 opiniones
# 5      509 opiniones
# 6       58 opiniones
# 7        8 opiniones
# 8
# 9       57 opiniones
# 10     757 opiniones
# 11     157 opiniones
# 12      27 opiniones
# 13       5 opiniones
# 14     109 opiniones
# 15     493 opiniones
# 16      13 opiniones
# 17      58 opiniones
# 18      33 opiniones
# 19      25 opiniones
# 20     509 opiniones
# 21       9 opiniones
# 22      22 opiniones
# 23       7 opiniones
# 24      45 opiniones
# 25      15 opiniones
# 26
# 27
# 28      19 opiniones
# 29       6 opiniones
# ...              ...
# 1532
# 1533
# 1534   103 opiniones
# 1535     5 opiniones
# 1536    14 opiniones
# 1537   212 opiniones
# 1538    72 opiniones
# 1539
# 1540     3 opiniones
# 1541       1 opinión
# 1542   382 opiniones
# 1543
# 1544
# 1545
# 1546
# 1547   208 opiniones
# 1548    72 opiniones
# 1549
# 1550
# 1551
# 1552
# 1553
# 1554
# 1555
# 1556
# 1557
# 1558
# 1559
# 1560
# 1561
#
# [1562 rows x 19 columns]

# %%
# Out:
# [('07/04/2019 16:20',
#   'Atrapalo',
#   'circo',
#   'Circo Alegría - Circo Sobre Agua, en Huelva',
#   'Circo',
#   '',
#   'Parque Comercial Marismas del Polvorín',
#   'Huelva',
#   '8',
#   '',
#   '',
#   '2019/04/07',
#   '2019/04/07',
#   '90 minutos',
#   'Castellano',
#   'Familiar',
#   '7.8',
#   'Bueno',
#   '103 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'circo',
#   'Circo Smile - Little Big Show, en Viladecans',
#   'Circo',
#   '',
#   'Parc de la Marina Viladecans',
#   'Viladecans',
#   '7',
#   '3',
#   '07 abr al 08 abr',
#   '2019/04/07',
#   '2019/04/08',
#   '100 minutos',
#   'Español',
#   'Familiar',
#   '7.2',
#   'Bueno',
#   '72 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'circo',
#   'Apocalipsis, en Santander',
#   'Circo',
#   '',
#   'El Sardinero',
#   'Santander',
#   '15',
#   '15',
#   '17 abr al 28 abr',
#   '2019/04/17',
#   '2019/04/28',
#   '120 minutos',
#   'Castellano',
#   'Adultos',
#   '',
#   '',
#   ''),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'circo',
#   'Circo Gottani - Famiglia Gottani, en Fuenlabrada ',
#   'Circo',
#   '',
#   'Carpa de circo - Calle de las Eras de Fuenlabrada',
#   'Fuenlabrada',
#   '7',
#   '5',
#   '12 abr al 14 abr',
#   '2019/04/12',
#   '2019/04/14',
#   '120 minutos',
#   'Español',
#   'Familiar',
#   '6.7',
#   'Correcto',
#   '3 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'circo',
#   'Apocalipsis, en Bilbao',
#   'Circo',
#   '',
#   'Bilbao Arena Miribilla',
#   'Bilbao',
#   '17,50',
#   '7,50',
#   '02 may al 05 may',
#   '2019/05/02',
#   '2019/05/05',
#   '120 minutos',
#   'Castellano',
#   'Adultos',
#   '8.7',
#   'Excelente',
#   '382 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'circo',
#   'Circo Universal en Zalla',
#   'Circo',
#   '',
#   'Carpa Circo Universal - Parking Eroski ',
#   'Zalla',
#   '10',
#   '',
#   '08 abr al 14 abr',
#   '2019/04/08',
#   '2019/04/14',
#   '1 hora y 50 minutos',
#   'Español',
#   'Para todas las edades',
#   '',
#   '',
#   ''),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'circo',
#   'Sueños - Circo Italiano, en Barakaldo',
#   'Circo',
#   '',
#   'Megapark',
#   'Barakaldo',
#   '9',
#   '5',
#   '12 abr al 28 abr',
#   '2019/04/12',
#   '2019/04/28',
#   '120 minutos',
#   'Español',
#   'Familiar',
#   '',
#   '',
#   ''),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'circo',
#   'Circo Quirós, en Guadalajara',
#   'Circo',
#   '',
#   'Recinto Ferial Guadalajara',
#   'Guadalajara',
#   '8',
#   '2',
#   '13 abr al 21 abr',
#   '2019/04/13',
#   '2019/04/21',
#   '120 minutos',
#   '',
#   'Familiar',
#   '',
#   '',
#   ''),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'circo',
#   'Circo Raluy Legacy - TheMagicFórmula, en Sabadell',
#   'Circo',
#   '',
#   'Carpa de Circo - Sabadell',
#   'Sabadell',
#   '6',
#   '',
#   '11 abr al 28 abr',
#   '2019/04/11',
#   '2019/04/28',
#   '120 minutos',
#   'Castellano',
#   'Familiar',
#   '9.3',
#   'Extraordinario',
#   '208 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'circo',
#   'Circo Smile - Little Big Show, en Castelldefels',
#   'Circo',
#   '',
#   'Carpa circo Castelldefels',
#   'Castelldefels',
#   '7',
#   '3',
#   '12 abr al 24 abr',
#   '2019/04/12',
#   '2019/04/24',
#   '100 minutos',
#   'Español',
#   'Familiar',
#   '7.2',
#   'Bueno',
#   '72 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'circo',
#   'Cul Kombat',
#   'Circo',
#   '',
#   'Sala Ultramar',
#   'Valencia',
#   '9',
#   '',
#   '12 abr al 14 abr',
#   '2019/04/12',
#   '2019/04/14',
#   '70 minutos',
#   'Valencià',
#   'Adultos',
#   '',
#   '',
#   ''),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'circo',
#   'Apocalipsis, Valladolid',
#   'Circo',
#   '',
#   'Recinto Ferial en Valladolid',
#   'Valladolid',
#   '17,50',
#   '7,50',
#   '06 jun al 09 jun',
#   '2019/06/06',
#   '2019/06/09',
#   '120 minutos',
#   'Castellano',
#   'Para todas las edades',
#   '',
#   '',
#   ''),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'circo',
#   'Apocalipsis, en Alicante',
#   'Circo',
#   '',
#   'Recinto Ferial de Rabasa ',
#   'Alicante',
#   '20',
#   '5',
#   '29 ago al 08 sep',
#   '2019/08/29',
#   '2019/09/08',
#   '120 minutos',
#   'Castellano',
#   'Adultos',
#   '',
#   '',
#   ''),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'circo',
#   'Circo Rojo en Granada',
#   'Circo',
#   '',
#   'Carpa de circo junto al Centro Comercial Alameda',
#   'Pulianas',
#   '15',
#   '10',
#   '12 abr al 21 abr',
#   '2019/04/12',
#   '2019/04/21',
#   '120 minutos',
#   'Castellano',
#   'Adultos',
#   '',
#   '',
#   ''),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'circo',
#   'Cirque du Soleil presenta Kooza en Gijón',
#   'Circo',
#   '',
#   'Muelle de la Osa, bajo la Gran Carpa',
#   'Gijón',
#   '30',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Para todas las edades',
#   '',
#   '',
#   ''),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'circo',
#   'Cirque du Soleil presenta Kooza en Madrid',
#   'Circo',
#   '',
#   'Bajo la Gran Carpa Blanca del escenario Puerta del Angel',
#   'Madrid',
#   '39',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Para todas las edades',
#   '',
#   '',
#   ''),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'circo',
#   'Cirque du Soleil presenta Kooza en Málaga',
#   'Circo',
#   '',
#   'Recinto Ferial Cortijo de Torres Málaga',
#   'Málaga',
#   '30',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Para todas las edades',
#   '',
#   '',
#   ''),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'circo',
#   'Cirque du Soleil presenta Kooza en Valencia',
#   'Circo',
#   '',
#   'Antigua estación de Grao, bajo la Gran Carpa',
#   'Valencia',
#   '34',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Para todas las edades',
#   '',
#   '',
#   ''),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'circo',
#   'Gran Festival Mundial del Circo Fofito Aragón - Los payasos de la Tele',
#   'Circo',
#   '',
#   'Palacio de Exposiciones y Congresos Los Planos',
#   'Teruel',
#   '12',
#   '13',
#   '',
#   '2019/04/14',
#   '2019/04/14',
#   'NA',
#   '',
#   'Para todas las edades',
#   '',
#   '',
#   ''),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'circo',
#   'Koselig',
#   'Circo',
#   '',
#   'Teatre-Auditori de Sant Cugat',
#   'Sant Cugat del Vallès',
#   '12',
#   '',
#   '',
#   '2019/04/07',
#   '2019/04/07',
#   '50 minutos',
#   '',
#   'Para todas las edades',
#   '',
#   '',
#   ''),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'circo',
#   'Máximo Óptimo',
#   'Circo',
#   '',
#   'Tarambana Teatro',
#   'Madrid',
#   '7',
#   '1',
#   '',
#   '2019/05/01',
#   '2019/05/01',
#   '60 minutos',
#   '',
#   'Para todas las edades',
#   '',
#   '',
#   ''),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'circo',
#   'Taxaaan...teatre de funàmbols',
#   'Circo',
#   '',
#   'SAT!',
#   'Barcelona',
#   '8',
#   '',
#   '11 may al 12 may',
#   '2019/05/11',
#   '2019/05/12',
#   '50',
#   'Castellano',
#   'Infantil',
#   '',
#   '',
#   ''),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'circo',
#   'Totem - Cirque du Soleil en Gran Canaria',
#   'Circo',
#   '',
#   'ExpoMeloneras - bajo la gran carpa blanca',
#   'Maspalomas',
#   '39',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Para todas las edades',
#   '',
#   '',
#   ''),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'teatro-danza',
#   'Atrapado x la magia',
#   'Magia',
#   '',
#   'Teatros Luchana',
#   'Madrid',
#   '8',
#   '6',
#   '19 abr al 28 abr',
#   '2019/04/19',
#   '2019/04/28',
#   'NA',
#   '',
#   'Para todas las edades',
#   '9.6',
#   'Extraordinario',
#   '25 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'teatro-danza',
#   'Oh, ¡Mami!',
#   'Comedia',
#   '',
#   'Teatro Borrás',
#   'Barcelona',
#   '19',
#   '5',
#   '07 abr al 26 may',
#   '2019/04/07',
#   '2019/05/26',
#   '90 minutos',
#   'Catalán',
#   'Adultos',
#   '',
#   '',
#   ''),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'teatro-danza',
#   'Santi Rodríguez - Infarto',
#   'Monólogos',
#   '',
#   'Club Capitol',
#   'Barcelona',
#   '20',
#   '',
#   '',
#   '2019/04/30',
#   '2019/04/30',
#   'NA',
#   '',
#   'Adultos',
#   '',
#   '',
#   ''),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'teatro-danza',
#   'Perfectos desconocidos',
#   'Teatro',
#   '',
#   'Teatro Reina Victoria',
#   'Madrid',
#   '12,60',
#   '5,40',
#   '07 abr al 23 jun',
#   '2019/04/07',
#   '2019/06/23',
#   '90 minutos',
#   'Castellano',
#   'Adultos',
#   '9.0',
#   'Extraordinario',
#   '572 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'teatro-danza',
#   'Monólogos de humor - Chocita del Loro Gran vía',
#   'Monólogos',
#   '',
#   'Teatro Chocita del Loro - Senator',
#   'Madrid',
#   '12',
#   '6',
#   '07 abr al 30 abr',
#   '2019/04/07',
#   '2019/04/30',
#   '1 hora y 30 minutos',
#   'Castellano',
#   'Adultos',
#   '8.7',
#   'Excelente',
#   '11543 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'teatro-danza',
#   'Nada es imposible - Mago Pop, en Madrid',
#   'Magia',
#   '',
#   'Teatro Rialto Madrid',
#   'Madrid',
#   '20,83',
#   '2,32',
#   '07 abr al 23 jun',
#   '2019/04/07',
#   '2019/06/23',
#   '90 minutos',
#   'Castellano',
#   'Para todas las edades',
#   '9.1',
#   'Extraordinario',
#   '1849 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'teatro-danza',
#   'Impro Show',
#   'Impro',
#   '',
#   'Teatreneu',
#   'Barcelona',
#   '12',
#   '8',
#   '07 abr al 31 may',
#   '2019/04/07',
#   '2019/05/31',
#   '80 minutos',
#   'Castellano',
#   'Adultos',
#   '8.6',
#   'Excelente',
#   '5288 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'teatro-danza',
#   'Burundanga',
#   'Comedia',
#   '',
#   'Teatro Maravillas',
#   'Madrid',
#   '16',
#   '4',
#   '07 abr al 30 jun',
#   '2019/04/07',
#   '2019/06/30',
#   '90 minutos',
#   'Español',
#   'Adultos',
#   '8.4',
#   'Muy bueno',
#   '12663 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'teatro-danza',
#   'La Golondrina con Carmen Maura, en Madrid',
#   'Teatro',
#   '',
#   'Teatro Infanta Isabel',
#   'Madrid',
#   '20',
#   '',
#   '07 abr al 05 may',
#   '2019/04/07',
#   '2019/05/05',
#   '90 minutos',
#   '',
#   'Adultos',
#   '8.9',
#   'Excelente',
#   '71 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'teatro-danza',
#   'El curioso incidente del perro a medianoche ',
#   'Teatro',
#   '',
#   'Teatro Marquina',
#   'Madrid',
#   '16',
#   '4',
#   '07 abr al 05 may',
#   '2019/04/07',
#   '2019/05/05',
#   '135 minutos',
#   'Castellano',
#   'Adultos',
#   '8.9',
#   'Excelente',
#   '668 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'teatro-danza',
#   'Las noches de El Club de la Comedia, en Madrid',
#   'Monólogos',
#   '',
#   'Teatro Rialto Madrid',
#   'Madrid',
#   '18',
#   '2',
#   '13 abr al 25 may',
#   '2019/04/13',
#   '2019/05/25',
#   '90 minutos',
#   '',
#   'Adultos',
#   '8.7',
#   'Excelente',
#   '2758 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'teatro-danza',
#   'La Tendresa',
#   'Teatro',
#   '',
#   'Teatre Poliorama',
#   'Barcelona',
#   '8',
#   '2',
#   '07 abr al 19 abr',
#   '2019/04/07',
#   '2019/04/19',
#   '110 minutos',
#   'Catalán',
#   'Adultos',
#   '9.2',
#   'Extraordinario',
#   '237 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'teatro-danza',
#   'David Guapo - #quenonosfrunjanlafiesta1, en Barcelona',
#   'Monólogos',
#   '',
#   'Club Capitol',
#   'Barcelona',
#   '23',
#   '',
#   '07 abr al 01 jun',
#   '2019/04/07',
#   '2019/06/01',
#   '1 hora y 20 minutos',
#   'Español',
#   'Adultos',
#   '9.0',
#   'Extraordinario',
#   '3269 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'teatro-danza',
#   'En ocasiones veo a Umberto - 2ª temporada',
#   'Comedia',
#   '',
#   'Teatro Muñoz Seca',
#   'Madrid',
#   '8,75',
#   '8,75',
#   '07 abr al 26 may',
#   '2019/04/07',
#   '2019/05/26',
#   '95 minutos',
#   'Castellano',
#   'Adultos',
#   '8.5',
#   'Excelente',
#   '2416 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'teatro-danza',
#   'Tinder Sorpresa - Andreu Casanova, en Barcelona',
#   'Monólogos',
#   '',
#   'Club Capitol Sala 2',
#   'Barcelona',
#   '14',
#   '6',
#   '07 abr al 21 abr',
#   '2019/04/07',
#   '2019/04/21',
#   'NA',
#   '',
#   'Adultos',
#   '9.2',
#   'Extraordinario',
#   '1234 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'teatro-danza',
#   'Toc Toc - 10º Temporada, en Madrid',
#   'Comedia',
#   '',
#   'Teatro Príncipe Gran Vía',
#   'Madrid',
#   '15',
#   '',
#   '07 abr al 05 may',
#   '2019/04/07',
#   '2019/05/05',
#   '110 minutos',
#   'Castellano',
#   'Adultos',
#   '8.2',
#   'Muy bueno',
#   '6279 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'teatro-danza',
#   'Dos más dos',
#   'Comedia',
#   '',
#   'Teatro Lara',
#   'Madrid',
#   '16',
#   '6',
#   '07 abr al 29 sep',
#   '2019/04/07',
#   '2019/09/29',
#   '100 min',
#   'Español',
#   'Adultos',
#   '8.6',
#   'Excelente',
#   '1325 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'teatro-danza',
#   'Ben - Hur',
#   'Comedia',
#   '',
#   'Teatro La Latina',
#   'Madrid',
#   '16,50',
#   '5,50',
#   '07 abr al 26 may',
#   '2019/04/07',
#   '2019/05/26',
#   '100 minutos',
#   'Castellano',
#   'Adultos',
#   '7.7',
#   'Bueno',
#   '25 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'teatro-danza',
#   'Los hombres son de Marte y las mujeres de Venus, en Madrid ',
#   'Comedia',
#   '',
#   'Nuevo Teatro Alcalá - Sala 2',
#   'Madrid',
#   '11,40',
#   '7,60',
#   '07 abr al 09 jun',
#   '2019/04/07',
#   '2019/06/09',
#   '90 minutos',
#   'Castellano',
#   'Adultos',
#   '8.4',
#   'Muy bueno',
#   '2439 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'teatro-danza',
#   'Señora de Rojo Sobre Fondo Gris',
#   'Teatro',
#   '',
#   'Teatre Romea',
#   'Barcelona',
#   '19',
#   '2',
#   '07 abr al 12 may',
#   '2019/04/07',
#   '2019/05/12',
#   '90 minutos',
#   'Castellano',
#   'Adultos',
#   '8.9',
#   'Excelente',
#   '18 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'teatro-danza',
#   '100% Toni Moog - 2ª temporada',
#   'Monólogos',
#   '',
#   'Club Capitol',
#   'Barcelona',
#   '15',
#   '4',
#   '07 abr al 05 may',
#   '2019/04/07',
#   '2019/05/05',
#   '70 minutos',
#   'Español',
#   'Adultos',
#   '8.0',
#   'Muy bueno',
#   '159 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'teatro-danza',
#   'Ponte en mi lugar',
#   'Comedia',
#   '',
#   'Teatro Muñoz Seca',
#   'Madrid',
#   '8,75',
#   '8,75',
#   '07 abr al 26 may',
#   '2019/04/07',
#   '2019/05/26',
#   '80 minutos',
#   'Castellano',
#   'Adultos',
#   '8.8',
#   'Excelente',
#   '682 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'teatro-danza',
#   'Miguel Lago Pone Orden, en Madrid',
#   'Monólogos',
#   '',
#   'Teatro Reina Victoria',
#   'Madrid',
#   '16',
#   '2',
#   '12 abr al 29 jun',
#   '2019/04/12',
#   '2019/06/29',
#   '90 minutos aprox',
#   'Catellano',
#   'Adultos',
#   '9.3',
#   'Extraordinario',
#   '1133 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'teatro-danza',
#   'Yo sobreviví a la EGB',
#   'Monólogos',
#   '',
#   'Aquitània Teatre',
#   'Barcelona',
#   '14',
#   '4',
#   '13 abr al 18 may',
#   '2019/04/13',
#   '2019/05/18',
#   '75 minutos aproximadamente',
#   'Español',
#   'Adultos',
#   '9.2',
#   'Extraordinario',
#   '1229 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'teatro-danza',
#   'Nada es imposible - Mago Pop, en Barcelona',
#   'Magia',
#   '',
#   'Teatre Victòria (Barcelona)',
#   'Barcelona',
#   '16,50',
#   '',
#   '18 sep al 13 oct',
#   '2019/09/18',
#   '2019/10/13',
#   '90 minutos',
#   'Castellano',
#   'Para todas las edades',
#   '9.1',
#   'Extraordinario',
#   '1840 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'teatro-danza',
#   'David Guapo - #quenonosfrunjanlafiesta1, en Mallorca',
#   'Monólogos',
#   '',
#   'Trui Teatre',
#   'Palma de Mallorca',
#   '18',
#   '',
#   '19 abr al 20 abr',
#   '2019/04/19',
#   '2019/04/20',
#   'NA',
#   '',
#   'Para todas las edades',
#   '9.0',
#   'Extraordinario',
#   '3248 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'teatro-danza',
#   'Els homes són de Mart i les dones de Venus',
#   'Monólogos',
#   '',
#   'Club Capitol Sala 2',
#   'Barcelona',
#   '16',
#   '3',
#   '07 abr al 19 may',
#   '2019/04/07',
#   '2019/05/19',
#   '90 minutos',
#   'Catalán',
#   'Adultos',
#   '8.4',
#   'Muy bueno',
#   '1572 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'teatro-danza',
#   'Los Morancos, en Madrid - x 40 +',
#   'Teatro',
#   '',
#   'Teatro Nuevo Apolo',
#   'Madrid',
#   '27',
#   '',
#   '12 abr al 28 abr',
#   '2019/04/12',
#   '2019/04/28',
#   '90 minutos',
#   'Español',
#   'Para todas las edades',
#   '9.2',
#   'Extraordinario',
#   '458 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'teatro-danza',
#   'Daniel Collado - 12% Ilusionismo para genios',
#   'Magia',
#   '',
#   'Sala 12%',
#   'Madrid',
#   '18',
#   '7',
#   '10 abr al 31 may',
#   '2019/04/10',
#   '2019/05/31',
#   '90 minutos',
#   'Español',
#   'Adultos',
#   '9.8',
#   'Extraordinario',
#   '565 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'teatro-danza',
#   'Federico García',
#   'Danza',
#   '',
#   'Teatre Goya',
#   'Barcelona',
#   '15',
#   '9',
#   '07 abr al 28 abr',
#   '2019/04/07',
#   '2019/04/28',
#   '90 minutos',
#   'Castellano',
#   'Adultos',
#   '9.5',
#   'Extraordinario',
#   '56 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'teatro-danza',
#   'Jamming Show, en Madrid',
#   'Impro',
#   '',
#   'Teatro Maravillas',
#   'Madrid',
#   '13',
#   '5',
#   '12 abr al 29 jun',
#   '2019/04/12',
#   '2019/06/29',
#   'NA',
#   '',
#   'Adultos',
#   '8.7',
#   'Excelente',
#   '2844 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'teatro-danza',
#   'El Sentido del Humor - Dos Tontos y Yo',
#   'Comedia',
#   '',
#   'Teatre Coliseum',
#   'Barcelona',
#   '25',
#   '',
#   '',
#   '2019/04/07',
#   '2019/04/07',
#   'NA',
#   '',
#   'Adultos',
#   '6.4',
#   'Correcto',
#   '39 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'teatro-danza',
#   'Álex Clavero - #mimadreestrendingtopic, en Madrid',
#   'Monólogos',
#   '',
#   'Cine Palacio de la Prensa - Sala 1',
#   'Madrid',
#   '12',
#   '',
#   '27 abr al 29 jun',
#   '2019/04/27',
#   '2019/06/29',
#   '70 minutos',
#   'Castellano',
#   'Adultos',
#   '9.4',
#   'Extraordinario',
#   '1178 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'teatro-danza',
#   'Los futbolísimos, el musical ',
#   'Teatro',
#   '',
#   'Teatro La Latina',
#   'Madrid',
#   '7,80',
#   '4,20',
#   '13 abr al 28 abr',
#   '2019/04/13',
#   '2019/04/28',
#   '70 minutos',
#   'Castellano',
#   'Familiar',
#   '8.2',
#   'Muy bueno',
#   '128 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'teatro-danza',
#   'Las noches de El Club de la Comedia, en Barcelona',
#   'Monólogos',
#   '',
#   'Teatre Poliorama',
#   'Barcelona',
#   '18',
#   '2',
#   '13 abr al 27 abr',
#   '2019/04/13',
#   '2019/04/27',
#   '90 minutos aprox.',
#   'Castellano',
#   'Adultos',
#   '8.4',
#   'Muy bueno',
#   '1784 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'teatro-danza',
#   'Karim - Sólo para adultos, en Madrid',
#   'Monólogos',
#   '',
#   'Teatros Luchana',
#   'Madrid',
#   '16',
#   '2',
#   '13 abr al 01 may',
#   '2019/04/13',
#   '2019/05/01',
#   '70 min',
#   'Español',
#   'Adultos',
#   '9.4',
#   'Extraordinario',
#   '1158 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'teatro-danza',
#   'El llibre de la Selva',
#   'Teatro',
#   '',
#   'Teatreneu',
#   'Barcelona',
#   '10',
#   '5',
#   '07 abr al 05 may',
#   '2019/04/07',
#   '2019/05/05',
#   '65 minutos',
#   'Catalán',
#   'Infantil',
#   '9.1',
#   'Extraordinario',
#   '12 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'teatro-danza',
#   'El jefe',
#   'Comedia',
#   '',
#   'Arlequín Gran Vía Teatro',
#   'Madrid',
#   '12',
#   '8',
#   '07 abr al 28 abr',
#   '2019/04/07',
#   '2019/04/28',
#   'NA',
#   '',
#   'Adultos',
#   '7.8',
#   'Bueno',
#   '77 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'teatro-danza',
#   'Emociones - Espectáculo flamenco',
#   'Danza',
#   '',
#   'Teatro Flamenco Madrid',
#   'Madrid',
#   '16',
#   '9',
#   '07 abr al 28 dic',
#   '2019/04/07',
#   '2019/12/28',
#   '60 minutos sin descanso',
#   'Español',
#   'Adultos',
#   '8.5',
#   'Excelente',
#   '233 opiniones'),
#  ('07/04/2019 16:20',
#   'Atrapalo',
#   'teatro-danza',
#   'Vermunólogos',
#   'Monólogos',
#   '',
#   'Café Teatro Llantiol',
#   'Barcelona',
#   '10',
#   '4',
#   '12 abr al 26 abr',
#   '2019/04/12',
#   '2019/04/26',
#   '2 horas',
#   'Español',
#   'Adultos',
#   '9.2',
#   'Extraordinario',
#   '1419 opiniones')]

# %%
#Sacar_atributos(espectaculos2[1])



# Sacamos el listado de espectaculos y ubicaciones
for cont,i in enumerate(espectaculos2):
    ubicacion = i.find_all(class_="info")[0].span.text.strip("\n").strip().split("\n")[0]
    print(cont," ",Sacar_atributos(i)[3], " ", ubicacion)
# Out:
# 0   Circo Alegría - Circo Sobre Agua, en Huelva   Parque Comercial Marismas del Polvorín
# 1   Sueños - Circo Italiano, en Santander   Carpa de Circo en Parking del Sardinero
# 2   Gran Circo Alaska, en Cartagena   Recinto frente al C.C. Mandarache
# 3   Circo Raluy Legacy - TheMagicFórmula, en Granollers   Recinto Ferial de Granollers
# 4   Circo Smile - Little Big Show, en Viladecans   Parc de la Marina Viladecans
# 5   Apocalipsis, en Santander   El Sardinero
# 6   Circo Gottani - Famiglia Gottani, en Fuenlabrada    Carpa de circo - Calle de las Eras de Fuenlabrada
# 7   Apocalipsis, en Vigo   Instituto Feiral de Vigo (IFEVI)
# 8   Había una vez...en Puertollano   Carpa de circo en Puertollano - junto a la plaza de toros
# 9   Apocalipsis, en Bilbao   Bilbao Arena Miribilla
# 10   Sueños - Circo Italiano, en Barakaldo   Megapark
# 11   Circo Quirós, en Guadalajara   Recinto Ferial Guadalajara
# 12   Circo Raluy Legacy - TheMagicFórmula, en Sabadell   Carpa de Circo - Sabadell
# 13   Circo Universal en Zalla   Carpa Circo Universal - Parking Eroski
# 14   Circo Smile - Little Big Show, en Castelldefels   Carpa circo Castelldefels
# 15   Cul Kombat   Sala Ultramar
# 16   Apocalipsis, en Alicante   Recinto Ferial de Rabasa
# 17   Apocalipsis, Valladolid   Recinto Ferial en Valladolid
# 18   Circo Rojo en Granada   Carpa de circo junto al Centro Comercial Alameda
# 19   Cirque du Soleil presenta Kooza en Gijón   Muelle de la Osa, bajo la Gran Carpa
# 20   Cirque du Soleil presenta Kooza en Madrid   Bajo la Gran Carpa Blanca del escenario Puerta del Angel
# 21   Cirque du Soleil presenta Kooza en Málaga   Recinto Ferial Cortijo de Torres Málaga
# 22   Cirque du Soleil presenta Kooza en Valencia   Antigua estación de Grao, bajo la Gran Carpa
# 23   Gran Festival Mundial del Circo Fofito Aragón - Los payasos de la Tele   Palacio de Exposiciones y Congresos Los Planos
# 24   Koselig   Teatre-Auditori de Sant Cugat
# 25   Máximo Óptimo   Tarambana Teatro
# 26   Taxaaan...teatre de funàmbols   SAT!
# 27   Totem - Cirque du Soleil en Gran Canaria   ExpoMeloneras - bajo la gran carpa blanca

# %%
espectaculos_bbdd = pd.read_csv(path, encoding = "ISO-8859-1", keep_default_na=False)  # [JON: En Pandas?]
temp = []
for fila in espectaculos_bbdd.iterrows():
    temp.append(tuple(fila[1])) # generamos una lista de tuplas. En el indice 0 se guarda el indice de fila
    
espectaculos_bbdd = temp
    
    # Sacamos los espectaculos nuevos que todavía no están en la bbdd
    
espectaculos = [atrib for atrib in (espectaculo[1:] for espectaculo in espectaculos_original)]
espectaculos2 = [atrib for atrib in ((espectaculo[3], espectaculo[6]) for espectaculo in espectaculos_original)]

espectaculos_bbdd = [atrib for atrib in (espectaculo[1:] for espectaculo in espectaculos_bbdd)]
espectaculos_bbdd2 = [atrib for atrib in ((espectaculo[2],espectaculo[5]) for espectaculo in espectaculos_bbdd)]
espectaculos_bbdd2
# Out:
# [('Circo Alegría - Circo Sobre Agua, en Huelva',
#   'Parque Comercial Marismas del Polvorín'),
#  ('Sueños - Circo Italiano, en Santander',
#   'Carpa de Circo en Parking del Sardinero'),
#  ('Gran Circo Alaska, en Cartagena', 'Recinto frente al C.C. Mandarache'),
#  ('Circo Raluy Legacy - TheMagicFórmula, en Granollers',
#   'Recinto Ferial de Granollers'),
#  ('Circo Smile - Little Big Show, en Viladecans',
#   'Parc de la Marina Viladecans'),
#  ('Apocalipsis, en Santander', 'El Sardinero')]

# %%
espectaculos2
# Out:
# [('Circo Alegría - Circo Sobre Agua, en Huelva',
#   'Parque Comercial Marismas del Polvorín'),
#  ('Sueños - Circo Italiano, en Santander',
#   'Carpa de Circo en Parking del Sardinero'),
#  ('Gran Circo Alaska, en Cartagena', 'Recinto frente al C.C. Mandarache'),
#  ('Circo Raluy Legacy - TheMagicFórmula, en Granollers',
#   'Recinto Ferial de Granollers'),
#  ('Circo Smile - Little Big Show, en Viladecans',
#   'Parc de la Marina Viladecans'),
#  ('Apocalipsis, en Santander', 'El Sardinero'),
#  ('Circo Gottani - Famiglia Gottani, en Fuenlabrada ',
#   'Carpa de circo - Calle de las Eras de Fuenlabrada'),
#  ('Apocalipsis, en Vigo', 'Instituto Feiral de Vigo (IFEVI)'),
#  ('Había una vez...en Puertollano',
#   'Carpa de circo en Puertollano - junto a la plaza de toros'),
#  ('Apocalipsis, en Bilbao', 'Bilbao Arena Miribilla'),
#  ('Sueños - Circo Italiano, en Barakaldo', 'Megapark'),
#  ('Circo Quirós, en Guadalajara', 'Recinto Ferial Guadalajara'),
#  ('Circo Raluy Legacy - TheMagicFórmula, en Sabadell',
#   'Carpa de Circo - Sabadell'),
#  ('Circo Universal en Zalla', 'Carpa Circo Universal - Parking Eroski '),
#  ('Circo Smile - Little Big Show, en Castelldefels',
#   'Carpa circo Castelldefels'),
#  ('Cul Kombat', 'Sala Ultramar'),
#  ('Apocalipsis, en Alicante', 'Recinto Ferial de Rabasa '),
#  ('Apocalipsis, Valladolid', 'Recinto Ferial en Valladolid'),
#  ('Circo Rojo en Granada', 'Carpa de circo junto al Centro Comercial Alameda'),
#  ('Cirque du Soleil presenta Kooza en Gijón',
#   'Muelle de la Osa, bajo la Gran Carpa'),
#  ('Cirque du Soleil presenta Kooza en Madrid',
#   'Bajo la Gran Carpa Blanca del escenario Puerta del Angel'),
#  ('Cirque du Soleil presenta Kooza en Málaga',
#   'Recinto Ferial Cortijo de Torres Málaga'),
#  ('Cirque du Soleil presenta Kooza en Valencia',
#   'Antigua estación de Grao, bajo la Gran Carpa'),
#  ('Gran Festival Mundial del Circo Fofito Aragón - Los payasos de la Tele',
#   'Palacio de Exposiciones y Congresos Los Planos'),
#  ('Koselig', 'Teatre-Auditori de Sant Cugat'),
#  ('Máximo Óptimo', 'Tarambana Teatro'),
#  ('Taxaaan...teatre de funàmbols', 'SAT!'),
#  ('Totem - Cirque du Soleil en Gran Canaria',
#   'ExpoMeloneras - bajo la gran carpa blanca')]

# %%
set(espectaculos2) & set(espectaculos_bbdd2)
# Out:
# {('Apocalipsis, en Santander', 'El Sardinero'),
#  ('Circo Alegría - Circo Sobre Agua, en Huelva',
#   'Parque Comercial Marismas del Polvorín'),
#  ('Circo Raluy Legacy - TheMagicFórmula, en Granollers',
#   'Recinto Ferial de Granollers'),
#  ('Circo Smile - Little Big Show, en Viladecans',
#   'Parc de la Marina Viladecans'),
#  ('Gran Circo Alaska, en Cartagena', 'Recinto frente al C.C. Mandarache'),
#  ('Sueños - Circo Italiano, en Santander',
#   'Carpa de Circo en Parking del Sardinero')}

# %%
#registros_de_bbdd = (set(espectaculos_bbdd2) - set(espectaculos2))
#registros_a _bbdd = set(espectaculos2) | registros_de_bbdd

espectaculos_bbdd = pd.read_csv(path, encoding = "ISO-8859-1", keep_default_na=False)  # [JON: En Pandas?]
espectaculos_cargar = []

for fila in espectaculos_bbdd.iterrows():
    identificador_registro = (fila[1][3],fila[1][6])
    if identificador_registro not in espectaculos2:
        espectaculos_cargar.append(tuple(fila[1]))
        #espectaculos.append(tuple(fila[1]))
        #print((fila[1][3],fila[1][6])," ", (fila[1][3],fila[1][6]) in espectaculos2 ) 
    # temp.append(tuple(fila[1])) # generamos una lista de tuplas. En el indice 0 se guarda el indice de fila


for espectaculo in espectaculos:
    espectaculo = [elem for elem in espectaculo]
    espectaculo.insert(0,time.strftime("%d/%m/%Y %H:%M"))
    espectaculos_cargar.append(tuple(espectaculo))

len(espectaculos_cargar)
# Out:
# 35
